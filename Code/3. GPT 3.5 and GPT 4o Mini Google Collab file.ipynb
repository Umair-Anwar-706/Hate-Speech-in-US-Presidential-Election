# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.1/374.1 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# Creating a dummy DataFrame with additional columns
data = {
    'post_id': [1, 2, 3, 4],
    'user': ['user123', 'hiker_gal', 'tech_guy', 'vegan_life'],
    'timestamp': ['2024-09-14 10:23:45', '2024-09-13 14:30:12', '2024-09-12 09:15:00', '2024-09-11 17:05:30'],
    'upvotes': [15, 42, 7, 25],
    'textual_col': [
        "I recently started using a new productivity app, and it's made a huge difference in my daily routine. "
        "However, I'm concerned about the amount of personal data it seems to collect. Has anyone else noticed this? "
        "Do you think it's worth it to continue using it despite the privacy concerns?",

        "Just got back from an amazing hike! The weather was perfect, and the views were incredible. "
        "Highly recommend checking out this trail if you're ever in the area. Also, make sure to bring plenty of water - it was a long one!",

        "In my opinion, the recent changes to the platform are a huge step backward. The new interface is clunky and slow, "
        "and it's become much harder to find the content I'm interested in. Anyone else feel the same way?",

        "I have been experimenting with a vegan diet for the past month, and I feel more energetic than ever. "
        "Has anyone else tried going vegan, and what were your experiences like? Any tips or recipes to share?"
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df.head()
# Out:
#    post_id        user            timestamp  upvotes  \
# 0        1     user123  2024-09-14 10:23:45       15
# 1        2   hiker_gal  2024-09-13 14:30:12       42
# 2        3    tech_guy  2024-09-12 09:15:00        7
# 3        4  vegan_life  2024-09-11 17:05:30       25
#
#                                          textual_col
# 0  I recently started using a new productivity ap...
# 1  Just got back from an amazing hike! The weathe...
# 2  In my opinion, the recent changes to the platf...
# 3  I have been experimenting with a vegan diet fo...

# %%
from openai import OpenAI
import pandas as pd

# Set up the OpenAI client with your API key
client = OpenAI(api_key="sk-cH6vkWQ65M7zG9ycEGDQ8QeDU1ewgnFGrydRf6XCdGT3BlbkFJFa72OxcnXkEL-tpidEwCoJ7dvfzO0FQBqHNd9bmNYA")  # Replace with your actual key

# Function to send prompt and receive response from GPT
def chat_gpt(prompt):
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",  # Using the gpt-3.5-turbo model
            messages=[{"role": "user", "content": prompt}]
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Error processing prompt: {prompt}\nError message: {e}")
        return "Error"

# Example prompt template
prompt_template = "Given the text: '{text}', categorize it as 'Biased' or 'Non-biased' based on its content."

# Create the DataFrame
df = pd.DataFrame(data)

# Apply the function to the DataFrame and create a new column for the results
df['category'] = df['textual_col'].apply(lambda x: chat_gpt(prompt_template.format(text=x)))

# Display the updated DataFrame
df.head()
# Out:
#    post_id        user            timestamp  upvotes  \
# 0        1     user123  2024-09-14 10:23:45       15
# 1        2   hiker_gal  2024-09-13 14:30:12       42
# 2        3    tech_guy  2024-09-12 09:15:00        7
# 3        4  vegan_life  2024-09-11 17:05:30       25
#
#                                          textual_col    category
# 0  I recently started using a new productivity ap...  Non-biased
# 1  Just got back from an amazing hike! The weathe...      Biased
# 2  In my opinion, the recent changes to the platf...      Biased
# 3  I have been experimenting with a vegan diet fo...  Non-biased
